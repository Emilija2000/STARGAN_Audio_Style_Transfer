# %%
# !pip freeze

# %%
# !pip install soundfile

# %%
# !pip uninstall librosa -y

# %%
# !pip install git+https://github.com/librosa/librosa.git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "drive/My Drive/Audio_Style_Transfer"
# Out:
# /content/drive/My Drive/Audio_Style_Transfer

# %%
import dataloader
import torch
import pickle

with open('pickle//audio_lambda8820_96.pickle','rb') as f:
    spect = pickle.load(f)
with open('pickle//mean_lambda8820_96.pickle','rb') as f:
    mean = pickle.load(f)
with open('pickle//sigma_lambda8820_96.pickle','rb') as f:
    sigma = pickle.load(f)
    
dataloader.writeAudio(spect, 22050,mean,sigma,'3cls_lambda8820_96e')
